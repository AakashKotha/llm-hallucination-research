# %% [markdown]
# # Measuring Hallucination Rate in LLMs Across Domains and Model Versions
# ## Dataset Creation Phase
#
# ### Overview
# This notebook contains the code for creating our structured dataset by sampling questions from established public datasets across five knowledge domains. We will collect 80 questions from each domain to create a balanced dataset for LLM hallucination analysis.
#
# ### Target Dataset Structure
# - **Total Questions:** 400 (80 per domain)
# - **Domains:** General Knowledge, Science, History, Pop Culture, Politics
# - **Models to Test:** GPT-3.5-turbo, Claude 3 Sonnet, GPT-4o
# - **Expected Total Responses:** 1,200
#
# ### Data Sources
# - **General Knowledge:** TriviaQA - Trivia-style Q&A with verified answers
# - **Science:** SciQ - Middle-school science questions
# - **History:** Natural Questions - Questions grounded in Wikipedia
# - **Pop Culture:** HotpotQA - Multi-hop Q&A with supporting passages
# - **Politics/Current Affairs:** NewsQA - Q&A over news articles

# %% [markdown]
# ## 1. General Knowledge Questions (TriviaQA Dataset)
#
# ### Dataset Information
# - **Source:** TriviaQA (unfiltered-web-dev.json)
# - **Target Sample:** 80 questions
# - **Domain:** General Knowledge

# %%
import json
import csv
import random

# -------------------------------
# Step 1: Load the TriviaQA dataset
# -------------------------------
# Source: https://nlp.cs.washington.edu/triviaqa/
with open('triviaqa-unfiltered/unfiltered-web-dev.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# -------------------------------
# Step 2: Randomly sample 80 questions
# -------------------------------
samples = random.sample(data['Data'], k=80)

# -------------------------------
# Step 3: Write to CSV with required format
# -------------------------------
with open('qna_dataset.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow(['question_id', 'question_text', 'domain', 'ground_truth'])

    for idx, item in enumerate(samples, start=1):
        question_text = item.get('Question', '').strip()
        answer = item.get('Answer', {}).get('Value', '').strip()
        domain = "General Knowledge"
        writer.writerow([idx, question_text, domain, answer])

# %% [markdown]
# ## 2. Science Questions (SciQ Dataset)
#
# ### Dataset Information
# - **Source:** SciQ (Hugging Face: allenai/sciq)
# - **Target Sample:** 80 questions
# - **Domain:** Science

# %%
from datasets import load_dataset
import csv
import random

# -------------------------------
# Step 1: Load the SciQ dataset
# -------------------------------
# Source: https://huggingface.co/datasets/allenai/sciq
dataset = load_dataset("allenai/sciq")

# -------------------------------
# Step 2: Randomly sample 80 questions from train split
# -------------------------------
train_data = list(dataset['train'])
samples = random.sample(train_data, k=80)

# -------------------------------
# Step 3: Append to existing CSV file
# -------------------------------
with open('qna_dataset.csv', 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    
    for idx, item in enumerate(samples, start=81):  # Start from 81 to continue numbering
        question_text = item.get('question', '').strip()
        answer = item.get('correct_answer', '').strip()
        domain = "Science"
        writer.writerow([idx, question_text, domain, answer])

# %% [markdown]
# ## 3. History Questions (Natural Questions Dataset)
#
# ### Dataset Information
# - **Source:** Natural Questions (nq_open)
# - **Target Sample:** 80 questions
# - **Domain:** History

# %%
from datasets import load_dataset
import csv
import random

# -------------------------------
# Step 1: Load the Natural Questions (open) dataset
# -------------------------------
# Source: https://huggingface.co/datasets/nq_open
dataset = load_dataset("nq_open")

# -------------------------------
# Step 2: Randomly sample 80 questions from train split
# -------------------------------
train_data = list(dataset['train'])
samples = random.sample(train_data, k=80)

# -------------------------------
# Step 3: Append to existing CSV file
# -------------------------------
with open('qna_dataset.csv', 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    
    for idx, item in enumerate(samples, start=161):  # Start from 161 to continue numbering
        question_text = item.get('question', '').strip()
        # NQ open has answers as a list, join all valid answers with commas
        answer_list = item.get('answer', [])
        if answer_list:
            # Join multiple answers with ", " separator
            answer = ', '.join([ans.strip() for ans in answer_list if ans.strip()])
        else:
            answer = ''
        domain = "History"
        writer.writerow([idx, question_text, domain, answer])

# %% [markdown]
# ## 4. Pop Culture Questions (HotpotQA Dataset)
#
# ### Dataset Information
# - **Source:** HotpotQA (hotpot_qa)
# - **Target Sample:** 80 questions
# - **Domain:** Pop Culture

# %%
from datasets import load_dataset
import csv
import random

# -------------------------------
# Step 1: Load the HotpotQA dataset
# -------------------------------
# Source: https://huggingface.co/datasets/hotpot_qa
dataset = load_dataset("hotpot_qa", "fullwiki", trust_remote_code=True)

# -------------------------------
# Step 2: Randomly sample 80 questions from train split
# -------------------------------
train_data = list(dataset['train'])
samples = random.sample(train_data, k=80)

# -------------------------------
# Step 3: Append to existing CSV file
# -------------------------------
with open('qna_dataset.csv', 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    
    for idx, item in enumerate(samples, start=241):  # Start from 241 to continue numbering
        question_text = item.get('question', '').strip()
        answer = item.get('answer', '').strip()
        domain = "Pop Culture"
        writer.writerow([idx, question_text, domain, answer])
# Out:
# Downloading data:   0%|          | 0.00/566M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/47.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/46.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/90447 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/7405 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7405 [00:00<?, ? examples/s]

# %% [markdown]
# ## 5. Healthcare Questions (MedMCQA Dataset)
#
# ### Dataset Information
# - **Source:** MedMCQA (openlifescienceai/medmcqa)
# - **Target Sample:** 80 questions
# - **Domain:** Healthcare

# %%
from datasets import load_dataset
import csv
import random

# -------------------------------
# Step 1: Load the MedMCQA dataset
# -------------------------------
# Source: https://huggingface.co/datasets/openlifescienceai/medmcqa
dataset = load_dataset("openlifescienceai/medmcqa")

# -------------------------------
# Step 2: Filter out "except" questions and randomly sample 80
# -------------------------------
train_data = list(dataset['train'])

# Filter out questions with "except" patterns that need multiple choice context
filtered_questions = []
except_patterns = ['except', 'not', 'false', 'incorrect', 'all of the following', 'which of the following']

for item in train_data:
    question_text = item.get('question', '').lower()
    # Skip questions that contain "except" or similar patterns
    if not any(pattern in question_text for pattern in except_patterns):
        filtered_questions.append(item)

print(f"Filtered out {len(train_data) - len(filtered_questions)} 'except' questions")
print(f"Remaining questions: {len(filtered_questions)}")

# Sample 80 questions from filtered ones
samples = random.sample(filtered_questions, k=80)

# -------------------------------
# Step 3: Append to existing CSV file
# -------------------------------
with open('qna_dataset.csv', 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    
    for idx, item in enumerate(samples, start=321):  # Start from 321 to continue numbering
        question_text = item.get('question', '').strip()
        
        # MedMCQA has multiple choice answers, we need the correct one
        options = [
            item.get('opa', ''),
            item.get('opb', ''),
            item.get('opc', ''),
            item.get('opd', '')
        ]
        
        # Get the correct answer index (0=A, 1=B, 2=C, 3=D)
        correct_idx = item.get('cop', 0)  # cop = correct option
        answer = options[correct_idx].strip() if correct_idx < len(options) else ''
        
        domain = "Healthcare"
        writer.writerow([idx, question_text, domain, answer])
# Out:
# Filtered out 58593 'except' questions
# Remaining questions: 124229

# %% [markdown]
# ## Add Question Length Column
#
# Add `question_length` column to measure question complexity (character count) for hypothesis H3 testing.

# %%
import pandas as pd

# -------------------------------
# Step 1: Load the existing dataset
# -------------------------------
df = pd.read_csv('qna_dataset.csv')

# -------------------------------
# Step 2: Calculate question length (character count)
# -------------------------------
df['question_length'] = df['question_text'].str.len()

# -------------------------------
# Step 3: Save the updated dataset
# -------------------------------
df.to_csv('qna_dataset.csv', index=False)

# -------------------------------
# Step 4: Display summary statistics
# -------------------------------
print(f"\nFirst 5 rows with question lengths:")
print(df[['question_id', 'question_text', 'domain', 'question_length']].head())
# Out:
# First 5 rows with question lengths:
#    question_id                                      question_text  \
# 0            1         What is the most common bird in the world?
# 1            2  What British sitcom that aired from 1979 to 19...
# 2            3  May 4, 1904 saw the US begin construction the ...
# 3            4  "In a 2007 interview, which actor 'animatedly'...
# 4            5      In which US state are the Catskill Mountains?
#
#               domain  question_length
# 0  General Knowledge               42
# 1  General Knowledge              100
# 2  General Knowledge              193
# 3  General Knowledge              171
# 4  General Knowledge               45

# %% [markdown]
# ## GPT-3.5 Question Analysis
#
# ### Purpose: Use GPT-3.5 to analyze questions and add classification columns

# %%
import pandas as pd
from openai import OpenAI
import json
import time
from datetime import datetime

# -------------------------------
# Step 1: Setup OpenAI API (v1.0+)
# -------------------------------
# Set your OpenAI API key
client = OpenAI(api_key="YOUR_OPENAI_API_KEY_HERE")  # Replace with your actual API key


# -------------------------------
# Step 2: Load the existing dataset
# -------------------------------
df = pd.read_csv('qna_dataset.csv')

# -------------------------------
# Step 3: Define GPT-3.5 analysis function
# -------------------------------
def analyze_question_with_gpt(question_text):
    prompt = f"""
Analyze this question and provide ONLY a JSON response with these exact fields:

Question: "{question_text}"

Return JSON format:
{{
    "question_type": "closed-ended" or "open-ended",
    "question_nature": "topical" or "general", 
    "question_style": "qualitative" or "quantitative",
    "response_text": "answer to the question"
}}

Rules:
- question_type: "closed-ended" if the question has a clear, direct, factual answer. "open-ended" if it requires descriptive, subjective, or interpretive responses
- question_nature: "topical" if about specific current events/trends, "general" if timeless knowledge
- question_style: "quantitative" if involves numbers/measurements, "qualitative" otherwise  
- response_text: Provide appropriate answer - can be direct fact, explanation, or description as needed. No conversational phrases like "That's a great question" or "How do you feel about it". Just answer the question naturally and informatively.
"""

    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.1,
            max_tokens=200
        )
        
        # Parse the JSON response
        result = json.loads(response.choices[0].message.content.strip())
        return result
        
    except Exception as e:
        print(f"Error processing question: {e}")
        return {
            "question_type": "unknown",
            "question_nature": "unknown", 
            "question_style": "unknown",
            "response_text": "error"
        }

# -------------------------------
# Step 4: Process ALL 400 questions
# -------------------------------
print("Starting GPT-3.5 analysis for ALL questions...")
print(f"Processing {len(df)} questions...")

results = []
for idx, row in df.iterrows():
    print(f"Processing question {idx+1}/{len(df)}: {row['question_text'][:50]}...")
    
    # Analyze question with GPT-3.5
    analysis = analyze_question_with_gpt(row['question_text'])
    
    # Add collection date
    analysis['collection_date'] = datetime.now().strftime('%Y-%m-%d')
    
    results.append(analysis)
    
    # Add small delay to respect API rate limits
    time.sleep(0.5)
    
    # Save progress every 50 questions (in case of interruption)
    if (idx + 1) % 50 == 0:
        print(f"✅ Completed {idx + 1} questions - saving progress...")

# -------------------------------
# Step 5: Add new columns to dataframe
# -------------------------------
df['question_type'] = [r['question_type'] for r in results]
df['question_nature'] = [r['question_nature'] for r in results] 
df['question_style'] = [r['question_style'] for r in results]
df['response_text'] = [r['response_text'] for r in results]
df['collection_date'] = [r['collection_date'] for r in results]

# -------------------------------
# Step 6: Save enhanced dataset
# -------------------------------
df.to_csv('qna_dataset_GPT3.5.csv', index=False)

print("GPT-3.5 analysis complete!")
print(f"Saved enhanced dataset to 'qna_dataset_GPT3.5.csv'")

# Display sample results
print(f"\nSample results:")
print(df[['question_text', 'question_type', 'question_nature', 'question_style']].head())

# Show distribution of classifications
print(f"\nClassification distributions:")
print(f"Question Type: {df['question_type'].value_counts().to_dict()}")
print(f"Question Nature: {df['question_nature'].value_counts().to_dict()}")
print(f"Question Style: {df['question_style'].value_counts().to_dict()}")
# Out:
# Starting GPT-3.5 analysis for ALL questions...
# Processing 400 questions...
# Processing question 1/400: What is the most common bird in the world?...
# Processing question 2/400: What British sitcom that aired from 1979 to 1981 i...
# Processing question 3/400: May 4, 1904 saw the US begin construction the Cana...
# Processing question 4/400: "In a 2007 interview, which actor 'animatedly' bem...
# Processing question 5/400: In which US state are the Catskill Mountains?...
# Processing question 6/400: What was the name of Canada's first woman Prime Mi...
# Processing question 7/400: Who was the former wife of war hero Leonard Cheshi...
# Processing question 8/400: Who was the first British winner of the US Women’s...
# Processing question 9/400: What type of beer does Homer Simpson drink?...
# Processing question 10/400: Which role is being played in a recently released ...
# Processing question 11/400: What was the surname of the butler played by Gordo...
# Processing question 12/400: Which French phrase commonly used in English means...
# Processing question 13/400: Tuesday marks the birthday of lat night tv host Da...
# Processing question 14/400: The feathers of which bird are said to bring bad l...
# Processing question 15/400: St Thomas's Abbey, Brno in the Czech Republic was ...
# Processing question 16/400: What was introduced by the Volstead Act?...
# Processing question 17/400: What word is used in betting slang for odds of fiv...
# Processing question 18/400: In adventure literature, what lie in an unexplored...
# Processing question 19/400: "Rodney you plonka" and "This time next year we'll...
# Processing question 20/400: In medicine, if something is subcutaneous it is ap...
# Processing question 21/400: "Complete the proverb; ""Hope for the best....""?"...
# Processing question 22/400: The Asian Tsunami or Boxing day tsunami that hit T...
# Processing question 23/400: The youngest ever member of the Order of Merit was...
# Processing question 24/400: Which French aristocrat, revolutionary, politician...
# Processing question 25/400: Where would a dewclaw usually be found?...
# Processing question 26/400: In geometry, what name is given to a straight line...
# Processing question 27/400: In 1725 Catherine the First succeeded which Russia...
# Processing question 28/400: Which working-class dish gets its name from the fa...
# Processing question 29/400: The husband of Lara Lewington, In which field is M...
# Processing question 356/400: A girl with normal stature and minimal or absent p...
# Processing question 357/400: A child present with albinism. He should be evalua...
# Processing question 358/400: Which feature is found only in the left lung?...
# Processing question 359/400: Best absorbable monosaccharide...
# Processing question 360/400: The following patient on Methotrexate, steroids an...
# Processing question 361/400: Which scientific principle is the basis for thermo...
# Processing question 362/400: Neutral substances are transported across the cell...
# Processing question 363/400: What is meant by "Suppositions child" -...
# Processing question 364/400: Most accurate and safest method to diagnose viable...
# Processing question 365/400: The abnormal preoperative pulmonary function test ...
# Processing question 366/400: A 24 years old primigravida wt = 57 kg, Hb 11.0 gm...
# Processing question 367/400: Crown-Rump length of 120 mm means the gestational ...
# Processing question 368/400: Alpha 1a selective blocker is...
# Processing question 369/400: Quinsy is synonymous with -...
# Processing question 370/400: Most common site of cholangiocarcinoma?...
# Processing question 371/400: The immediate treatment of 10 kg weight infants pr...
# Processing question 372/400: The most frequent cause of fracture of a root tip
# ...
# Processing question 373/400: Cholangiocarcinoma most commonly metastases to-...
# Processing question 374/400: Drug resistance in Tuberculosis is due to ?...
# Processing question 375/400: IQ value of Imbecile according to weehsler Intelli...
# Processing question 376/400: A Clinical sign of mania is?...
# Processing question 377/400: The part of sequence of RNA coding for a protein a...
# Processing question 378/400: Damage to pneumotaxic center produces ?...
# Processing question 379/400: Painless effusions in joints in congenital syphili...
# Processing question 380/400: The complication least likely to occur in a case o...
# Processing question 381/400: In allergic pharyngitis, granularity in posterior ...
# Processing question 382/400: Development of labia majora is from...
# Processing question 383/400: Unilateral undescended around ?...
# Processing question 384/400: The largest bursa in the body is:...
# Processing question 385/400: A patient presented with a 1 X 1.5 cms growth on t...
# Processing question 386/400: Bluish tympanic membrane is seen in:...
# Processing question 387/400: Which one of the following marker is useful in dif...
# Processing question 388/400: Ascospore is...
# Processing question 389/400: Conclusive test for semen: Jharkhand 11...
# Processing question 390/400: A 80 years old male presented with lung abscess in...
# Processing question 391/400: Sigmoid volvulus rotation occurs...
# Processing question 392/400: A 25 year old female underwent septic aboion, whic...
# Processing question 393/400: What effect does hyperventilation have on the oxyg...
# Processing question 394/400: Deletion of one alpha globin gene on one chromosom...
# Processing question 395/400: True statement regarding Prevalence:...
# Processing question 396/400: Thyroid hormone receptor which is predominantly ex...
# Processing question 397/400: Investigation of choice for hydrocephalus in infan...
# Processing question 398/400: Renal vein thrombosis (RVT) may be seen in :...
# Processing question 399/400: In children below age of 8 years, high Level of cr...
# Processing question 400/400: Middle aged man presents with complaints of weakne...
# ✅ Completed 400 questions - saving progress...
# GPT-3.5 analysis complete!
# Saved enhanced dataset to 'qna_dataset_GPT3.5.csv'
#
# Sample results:
#                                        question_text question_type  \
# 0         What is the most common bird in the world?  closed-ended
# 1  What British sitcom that aired from 1979 to 19...  closed-ended
# 2  May 4, 1904 saw the US begin construction the ...  closed-ended
# 3  "In a 2007 interview, which actor 'animatedly'...  closed-ended
# 4      In which US state are the Catskill Mountains?  closed-ended
#
#   question_nature question_style
# 0         general    qualitative
# 1         general    qualitative
# 2         general    qualitative
# 3         topical    qualitative
# 4         general    qualitative
#
# Classification distributions:
# Question Type: {'closed-ended': 390, 'open-ended': 9, 'unknown': 1}
# Question Nature: {'general': 336, 'topical': 63, 'unknown': 1}
# Question Style: {'qualitative': 372, 'quantitative': 27, 'unknown': 1}

# %%
# Show distribution of classifications
print(f"\nClassification distributions:")
print(f"Question Type: {df['question_type'].value_counts().to_dict()}")
print(f"Question Nature: {df['question_nature'].value_counts().to_dict()}")
print(f"Question Style: {df['question_style'].value_counts().to_dict()}")
# Out:
# Classification distributions:
# Question Type: {'closed-ended': 391, 'open-ended': 9}
# Question Nature: {'general': 337, 'topical': 63}
# Question Style: {'qualitative': 373, 'quantitative': 27}

# %%
## Add Response Length Column

### Purpose: Add response_length column to measure GPT-3.5 response complexity (character count)

import pandas as pd

# -------------------------------
# Step 1: Load the existing dataset
# -------------------------------
df = pd.read_csv('qna_dataset_GPT3.5.csv')

# -------------------------------
# Step 2: Calculate response length (character count)
# -------------------------------
df['response_length'] = df['response_text'].str.len()

# -------------------------------
# Step 3: Save the updated dataset
# -------------------------------
df.to_csv('qna_dataset_GPT3.5.csv', index=False)

# -------------------------------
# Step 4: Display summary statistics
# -------------------------------
print("Response length column added successfully!")
print(f"\nDataset shape: {df.shape}")
print(f"\nResponse length statistics:")
print(df['response_length'].describe())

print(f"\nSample data with both lengths:")
print(df[['question_text', 'question_length', 'response_text', 'response_length']].head())
# Out:
# Response length column added successfully!
#
# Dataset shape: (400, 11)
#
# Response length statistics:
# count    400.000000
# mean      98.452500
# std       79.212336
# min        4.000000
# 25%       47.000000
# 50%       83.000000
# 75%      126.250000
# max      416.000000
# Name: response_length, dtype: float64
#
# Sample data with both lengths:
#                                        question_text  question_length  \
# 0         What is the most common bird in the world?               42
# 1  What British sitcom that aired from 1979 to 19...              100
# 2  May 4, 1904 saw the US begin construction the ...              193
# 3  "In a 2007 interview, which actor 'animatedly'...              171
# 4      In which US state are the Catskill Mountains?               45
#
#                                        response_text  response_length
# 0  The most common bird in the world is the domes...               85
# 1                                  To the Manor Born               17
# 2  The US president who provided iron backbone an...              178
# 3                                       Nicolas Cage               12
# 4                                           New York                8

# %% [markdown]
# ## GPT-4o Response Generation (All 400 Questions)
#
# ### Purpose: Generate responses using GPT-4o for all questions

# %%
import pandas as pd
from openai import OpenAI
import time
from datetime import datetime

# -------------------------------
# Step 1: Setup OpenAI API
# -------------------------------
client = OpenAI(api_key="YOUR_OPENAI_API_KEY_HERE")  # Replace with your actual API key

# -------------------------------
# Step 2: Load existing dataset into new dataframe
# -------------------------------
df_gpt4o = pd.read_csv('qna_dataset_GPT3.5.csv')

print(f"Processing ALL {len(df_gpt4o)} questions using GPT-4o...")

# -------------------------------
# Step 3: Define GPT-4o response function
# -------------------------------
def get_gpt4o_response(question_text):
    prompt = f"""
Provide appropriate answer - can be direct fact, explanation, or description as needed. No conversational phrases like "That's a great question" or "How do you feel about it". Just answer the question naturally and informatively.

Question: "{question_text}"
"""

    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.1,
            max_tokens=300
        )
        
        return response.choices[0].message.content.strip()
        
    except Exception as e:
        print(f"Error processing question: {e}")
        return "error"

# -------------------------------
# Step 4: Generate GPT-4o responses for ALL questions
# -------------------------------
print("Generating GPT-4o responses for all 400 questions...")

gpt4o_responses = []
for idx, row in df_gpt4o.iterrows():
    print(f"Processing question {idx+1}/{len(df_gpt4o)}: {row['question_text'][:50]}...")
    
    # Get GPT-4o response
    response = get_gpt4o_response(row['question_text'])
    gpt4o_responses.append(response)
    
    # Add small delay to respect API rate limits
    time.sleep(0.25)
    
    # Save progress every 50 questions (in case of interruption)
    if (idx + 1) % 50 == 0:
        print(f"Completed {idx + 1} questions - progress saved...")

# -------------------------------
# Step 5: Replace response columns with GPT-4o data
# -------------------------------
df_gpt4o['response_text'] = gpt4o_responses
df_gpt4o['response_length'] = df_gpt4o['response_text'].str.len()

# Update collection date
df_gpt4o['collection_date'] = datetime.now().strftime('%Y-%m-%d')

# -------------------------------
# Step 6: Save to new CSV
# -------------------------------
df_gpt4o.to_csv('qna_dataset_GPT4o.csv', index=False)

print("GPT-4o responses generated for all questions!")
print(f"Saved to 'qna_dataset_GPT4o.csv'")
print(f"\nDataset shape: {df_gpt4o.shape}")
# Out:
# Processing ALL 400 questions using GPT-4o...
# Generating GPT-4o responses for all 400 questions...
# Processing question 1/400: What is the most common bird in the world?...
# Processing question 2/400: What British sitcom that aired from 1979 to 1981 i...
# Processing question 3/400: May 4, 1904 saw the US begin construction the Cana...
# Processing question 4/400: "In a 2007 interview, which actor 'animatedly' bem...
# Processing question 5/400: In which US state are the Catskill Mountains?...
# Processing question 6/400: What was the name of Canada's first woman Prime Mi...
# Processing question 7/400: Who was the former wife of war hero Leonard Cheshi...
# Processing question 8/400: Who was the first British winner of the US Women’s...
# Processing question 9/400: What type of beer does Homer Simpson drink?...
# Processing question 10/400: Which role is being played in a recently released ...
# Processing question 11/400: What was the surname of the butler played by Gordo...
# Processing question 12/400: Which French phrase commonly used in English means...
# Processing question 13/400: Tuesday marks the birthday of lat night tv host Da...
# Processing question 14/400: The feathers of which bird are said to bring bad l...
# Processing question 15/400: St Thomas's Abbey, Brno in the Czech Republic was ...
# Processing question 16/400: What was introduced by the Volstead Act?...
# Processing question 17/400: What word is used in betting slang for odds of fiv...
# Processing question 18/400: In adventure literature, what lie in an unexplored...
# Processing question 19/400: "Rodney you plonka" and "This time next year we'll...
# Processing question 20/400: In medicine, if something is subcutaneous it is ap...
# Processing question 21/400: "Complete the proverb; ""Hope for the best....""?"...
# Processing question 22/400: The Asian Tsunami or Boxing day tsunami that hit T...
# Processing question 23/400: The youngest ever member of the Order of Merit was...
# Processing question 24/400: Which French aristocrat, revolutionary, politician...
# Processing question 25/400: Where would a dewclaw usually be found?...
# Processing question 26/400: In geometry, what name is given to a straight line...
# Processing question 27/400: In 1725 Catherine the First succeeded which Russia...
# Processing question 28/400: Which working-class dish gets its name from the fa...
# Processing question 29/400: The husband of Lara Lewington, In which field is M...
# Processing question 358/400: Which feature is found only in the left lung?...
# Processing question 359/400: Best absorbable monosaccharide...
# Processing question 360/400: The following patient on Methotrexate, steroids an...
# Processing question 361/400: Which scientific principle is the basis for thermo...
# Processing question 362/400: Neutral substances are transported across the cell...
# Processing question 363/400: What is meant by "Suppositions child" -...
# Processing question 364/400: Most accurate and safest method to diagnose viable...
# Processing question 365/400: The abnormal preoperative pulmonary function test ...
# Processing question 366/400: A 24 years old primigravida wt = 57 kg, Hb 11.0 gm...
# Processing question 367/400: Crown-Rump length of 120 mm means the gestational ...
# Processing question 368/400: Alpha 1a selective blocker is...
# Processing question 369/400: Quinsy is synonymous with -...
# Processing question 370/400: Most common site of cholangiocarcinoma?...
# Processing question 371/400: The immediate treatment of 10 kg weight infants pr...
# Processing question 372/400: The most frequent cause of fracture of a root tip
# ...
# Processing question 373/400: Cholangiocarcinoma most commonly metastases to-...
# Processing question 374/400: Drug resistance in Tuberculosis is due to ?...
# Processing question 375/400: IQ value of Imbecile according to weehsler Intelli...
# Processing question 376/400: A Clinical sign of mania is?...
# Processing question 377/400: The part of sequence of RNA coding for a protein a...
# Processing question 378/400: Damage to pneumotaxic center produces ?...
# Processing question 379/400: Painless effusions in joints in congenital syphili...
# Processing question 380/400: The complication least likely to occur in a case o...
# Processing question 381/400: In allergic pharyngitis, granularity in posterior ...
# Processing question 382/400: Development of labia majora is from...
# Processing question 383/400: Unilateral undescended around ?...
# Processing question 384/400: The largest bursa in the body is:...
# Processing question 385/400: A patient presented with a 1 X 1.5 cms growth on t...
# Processing question 386/400: Bluish tympanic membrane is seen in:...
# Processing question 387/400: Which one of the following marker is useful in dif...
# Processing question 388/400: Ascospore is...
# Processing question 389/400: Conclusive test for semen: Jharkhand 11...
# Processing question 390/400: A 80 years old male presented with lung abscess in...
# Processing question 391/400: Sigmoid volvulus rotation occurs...
# Processing question 392/400: A 25 year old female underwent septic aboion, whic...
# Processing question 393/400: What effect does hyperventilation have on the oxyg...
# Processing question 394/400: Deletion of one alpha globin gene on one chromosom...
# Processing question 395/400: True statement regarding Prevalence:...
# Processing question 396/400: Thyroid hormone receptor which is predominantly ex...
# Processing question 397/400: Investigation of choice for hydrocephalus in infan...
# Processing question 398/400: Renal vein thrombosis (RVT) may be seen in :...
# Processing question 399/400: In children below age of 8 years, high Level of cr...
# Processing question 400/400: Middle aged man presents with complaints of weakne...
# Completed 400 questions - progress saved...
# GPT-4o responses generated for all questions!
# Saved to 'qna_dataset_GPT4o.csv'
#
# Dataset shape: (400, 11)
#
# GPT-4o response length statistics:
# count     400.000000
# mean      253.672500
# std       203.662014
# min         8.000000
# 25%       101.000000
# 50%       207.500000
# 75%       349.750000
# max      1487.000000
# Name: response_length, dtype: float64
#
# Sample GPT-4o responses:
#                                        question_text  \
# 0         What is the most common bird in the world?
# 1  What British sitcom that aired from 1979 to 19...
# 2  May 4, 1904 saw the US begin construction the ...
# 3  "In a 2007 interview, which actor 'animatedly'...
# 4      In which US state are the Catskill Mountains?
#
#                                        response_text  response_length
# 0  The most common bird in the world is the domes...              276
# 1  The British sitcom that aired from 1979 to 198...              125
# 2  The construction of the Panama Canal began und...              236
# 3  In a 2007 interview, actor Antonio Banderas an...              265
# 4  The Catskill Mountains are located in the stat...               60

# %%
# -------------------------------
# Step 7: Show final statistics
# -------------------------------
print(f"\nGPT-4o response length statistics:")
print(df_gpt4o['response_length'].describe())

print(f"\nSample GPT-4o responses:")
print(df_gpt4o[['question_text', 'response_text', 'response_length']].head())
# Out:
# GPT-4o response length statistics:
# count     400.000000
# mean      253.672500
# std       203.662014
# min         8.000000
# 25%       101.000000
# 50%       207.500000
# 75%       349.750000
# max      1487.000000
# Name: response_length, dtype: float64
#
# Sample GPT-4o responses:
#                                        question_text  \
# 0         What is the most common bird in the world?
# 1  What British sitcom that aired from 1979 to 19...
# 2  May 4, 1904 saw the US begin construction the ...
# 3  "In a 2007 interview, which actor 'animatedly'...
# 4      In which US state are the Catskill Mountains?
#
#                                        response_text  response_length
# 0  The most common bird in the world is the domes...              276
# 1  The British sitcom that aired from 1979 to 198...              125
# 2  The construction of the Panama Canal began und...              236
# 3  In a 2007 interview, actor Antonio Banderas an...              265
# 4  The Catskill Mountains are located in the stat...               60

# %% [markdown]
# ## Claude 3.5 Sonnet Response Generation (All 400 Questions)
#
# ### Purpose: Generate responses using Claude 3.5 Sonnet for all questions

# %%
import pandas as pd
import anthropic
import time
from datetime import datetime

# -------------------------------
# Step 1: Setup Anthropic API
# -------------------------------
client = anthropic.Anthropic(api_key="YOUR_ANTHROPIC_API_KEY_HERE")  # Replace with your actual API key

# -------------------------------
# Step 2: Load existing dataset into new dataframe
# -------------------------------
df_claude = pd.read_csv('qna_dataset_GPT3.5.csv')

print(f"Processing ALL {len(df_claude)} questions using Claude 3.5 Sonnet...")

# -------------------------------
# Step 3: Define Claude 3.5 Sonnet response function
# -------------------------------
def get_claude_response(question_text):
    prompt = f"""
Provide appropriate answer - can be direct fact, explanation, or description as needed. No conversational phrases like "That's a great question" or "How do you feel about it". Just answer the question naturally and informatively.

Question: "{question_text}"
"""

    try:
        response = client.messages.create(
            model="claude-3-5-sonnet-20241022",  # Updated to latest Claude 3.5 Sonnet
            max_tokens=300,
            temperature=0.1,
            messages=[{"role": "user", "content": prompt}]
        )
        
        return response.content[0].text.strip()
        
    except Exception as e:
        print(f"Error processing question: {e}")
        return "error"

# -------------------------------
# Step 4: Generate Claude 3.5 Sonnet responses for ALL questions
# -------------------------------
print("Generating Claude 3.5 Sonnet responses for all 400 questions...")

claude_responses = []
for idx, row in df_claude.iterrows():
    print(f"Processing question {idx+1}/{len(df_claude)}: {row['question_text'][:50]}...")
    
    # Get Claude 3.5 Sonnet response
    response = get_claude_response(row['question_text'])
    claude_responses.append(response)
    
    # Add small delay to respect API rate limits
    time.sleep(0.25)
    
    # Save progress every 50 questions (in case of interruption)
    if (idx + 1) % 50 == 0:
        print(f"Completed {idx + 1} questions - progress saved...")

# -------------------------------
# Step 5: Replace response columns with Claude data
# -------------------------------
df_claude['response_text'] = claude_responses
df_claude['response_length'] = df_claude['response_text'].str.len()

# Update collection date
df_claude['collection_date'] = datetime.now().strftime('%Y-%m-%d')

# -------------------------------
# Step 6: Save to new CSV
# -------------------------------
df_claude.to_csv('qna_dataset_Claude3.5Sonnet.csv', index=False)

print("Claude 3.5 Sonnet responses generated for all questions!")
print(f"Saved to 'qna_dataset_Claude3.5Sonnet.csv'")
print(f"\nDataset shape: {df_claude.shape}")
# Out:
# Processing ALL 400 questions using Claude 3.5 Sonnet...
# Generating Claude 3.5 Sonnet responses for all 400 questions...
# Processing question 1/400: What is the most common bird in the world?...
# Processing question 2/400: What British sitcom that aired from 1979 to 1981 i...
# Processing question 3/400: May 4, 1904 saw the US begin construction the Cana...
# Processing question 4/400: "In a 2007 interview, which actor 'animatedly' bem...
# Processing question 5/400: In which US state are the Catskill Mountains?...
# Processing question 6/400: What was the name of Canada's first woman Prime Mi...
# Processing question 7/400: Who was the former wife of war hero Leonard Cheshi...
# Processing question 8/400: Who was the first British winner of the US Women’s...
# Processing question 9/400: What type of beer does Homer Simpson drink?...
# Processing question 10/400: Which role is being played in a recently released ...
# Processing question 11/400: What was the surname of the butler played by Gordo...
# Processing question 12/400: Which French phrase commonly used in English means...
# Processing question 13/400: Tuesday marks the birthday of lat night tv host Da...
# Processing question 14/400: The feathers of which bird are said to bring bad l...
# Processing question 15/400: St Thomas's Abbey, Brno in the Czech Republic was ...
# Processing question 16/400: What was introduced by the Volstead Act?...
# Processing question 17/400: What word is used in betting slang for odds of fiv...
# Processing question 18/400: In adventure literature, what lie in an unexplored...
# Processing question 19/400: "Rodney you plonka" and "This time next year we'll...
# Processing question 20/400: In medicine, if something is subcutaneous it is ap...
# Processing question 21/400: "Complete the proverb; ""Hope for the best....""?"...
# Processing question 22/400: The Asian Tsunami or Boxing day tsunami that hit T...
# Processing question 23/400: The youngest ever member of the Order of Merit was...
# Processing question 24/400: Which French aristocrat, revolutionary, politician...
# Processing question 25/400: Where would a dewclaw usually be found?...
# Processing question 26/400: In geometry, what name is given to a straight line...
# Processing question 27/400: In 1725 Catherine the First succeeded which Russia...
# Processing question 28/400: Which working-class dish gets its name from the fa...
# Processing question 29/400: The husband of Lara Lewington, In which field is M...
# Processing question 30/400: Raclette, Tilsit and Sbrinz are all types of which...
# Processing question 31/400: Who wrote the 1984 Booker Prize winning novel 'Hot...
# Processing question 32/400: Which TV series was won by a man named Paddy Doher...
# Processing question 33/400: Precisely where were the Winter Olympics of 1932 a...
# Processing question 34/400: In the TV sit-com 'Red Dwarf', what was the name o...
# Processing question 35/400: What was the former name of Manchester airport ?...
# Processing question 36/400: Which country shares a 530 km border with Saudi Ar...
# Processing question 37/400: The peaceful overthrow of the government in Czecho...
# Processing question 38/400: October 27, 1858 saw the birth of what totally bad...
# Processing question 39/400: Theon Greyjoy, a character in the television serie...
# Processing question 40/400: What nationality was the astronomer Copernicus ?...
# Processing question 41/400: Who won the 2007 Nobel Peace Prize for his environ...
# Processing question 42/400: In which Canadian territory is the Klondike...
# ...
# Processing question 373/400: Cholangiocarcinoma most commonly metastases to-...
# Processing question 374/400: Drug resistance in Tuberculosis is due to ?...
# Processing question 375/400: IQ value of Imbecile according to weehsler Intelli...
# Processing question 376/400: A Clinical sign of mania is?...
# Processing question 377/400: The part of sequence of RNA coding for a protein a...
# Processing question 378/400: Damage to pneumotaxic center produces ?...
# Processing question 379/400: Painless effusions in joints in congenital syphili...
# Processing question 380/400: The complication least likely to occur in a case o...
# Processing question 381/400: In allergic pharyngitis, granularity in posterior ...
# Processing question 382/400: Development of labia majora is from...
# Processing question 383/400: Unilateral undescended around ?...
# Processing question 384/400: The largest bursa in the body is:...
# Processing question 385/400: A patient presented with a 1 X 1.5 cms growth on t...
# Processing question 386/400: Bluish tympanic membrane is seen in:...
# Processing question 387/400: Which one of the following marker is useful in dif...
# Processing question 388/400: Ascospore is...
# Processing question 389/400: Conclusive test for semen: Jharkhand 11...
# Processing question 390/400: A 80 years old male presented with lung abscess in...
# Processing question 391/400: Sigmoid volvulus rotation occurs...
# Processing question 392/400: A 25 year old female underwent septic aboion, whic...
# Processing question 393/400: What effect does hyperventilation have on the oxyg...
# Processing question 394/400: Deletion of one alpha globin gene on one chromosom...
# Processing question 395/400: True statement regarding Prevalence:...
# Processing question 396/400: Thyroid hormone receptor which is predominantly ex...
# Processing question 397/400: Investigation of choice for hydrocephalus in infan...
# Processing question 398/400: Renal vein thrombosis (RVT) may be seen in :...
# Processing question 399/400: In children below age of 8 years, high Level of cr...
# Processing question 400/400: Middle aged man presents with complaints of weakne...
# Completed 400 questions - progress saved...
# Claude 3.5 Sonnet responses generated for all questions!
# Saved to 'qna_dataset_Claude35Sonnet.csv'
#
# Dataset shape: (400, 11)

# %%
# -------------------------------
# Step 7: Show final statistics
# -------------------------------
print(f"\nClaude 3.5 Sonnet response length statistics:")
print(df_claude['response_length'].describe())

print(f"\nSample Claude 3.5 Sonnet responses:")
print(df_claude[['question_text', 'response_text', 'response_length']].head())
# Out:
# Claude 3.5 Sonnet response length statistics:
# count     400.000000
# mean      391.595000
# std       199.831699
# min         6.000000
# 25%       250.750000
# 50%       349.000000
# 75%       501.750000
# max      1075.000000
# Name: response_length, dtype: float64
#
# Sample Claude 3.5 Sonnet responses:
#                                        question_text  \
# 0         What is the most common bird in the world?
# 1  What British sitcom that aired from 1979 to 19...
# 2  May 4, 1904 saw the US begin construction the ...
# 3  "In a 2007 interview, which actor 'animatedly'...
# 4      In which US state are the Catskill Mountains?
#
#                                        response_text  response_length
# 0  The House Sparrow (Passer domesticus) is the m...              403
# 1  To The Manor Born aired on BBC1 from 1979 to 1...              352
# 2  Theodore Roosevelt orchestrated Panama's indep...              646
# 3  Bill Murray made these comments about Garfield...              342
# 4  The Catskill Mountains are located in New York...              305

# %% [markdown]
# ## Hallucination Analysis for All Models (All Questions)
#
# ### Purpose: Analyze responses from GPT-3.5, GPT-4o, and Claude 3.5 Sonnet for hallucinations

# %%
import pandas as pd
from openai import OpenAI
import json
import time
from datetime import datetime

# -------------------------------
# Step 1: Setup OpenAI API
# -------------------------------
client = OpenAI(api_key="YOUR_OPENAI_API_KEY_HERE")  # Replace with your actual API key

# -------------------------------
# Step 2: Load all three datasets
# -------------------------------
files_to_process = [
    ('qna_dataset_GPT3.5.csv', 'qna_dataset_GPT3.5_final.csv'),
    ('qna_dataset_GPT4o.csv', 'qna_dataset_GPT4o_final.csv'),
    ('qna_dataset_Claude3.5Sonnet.csv', 'qna_dataset_Claude3.5Sonnet_final.csv')
]

print("Starting hallucination analysis for all 3 models (ALL questions)...")

# -------------------------------
# Step 3: Define hallucination analysis function
# -------------------------------
def analyze_response_for_hallucination(question, ground_truth, response_text):
    prompt = f"""
Analyze this Q&A response and provide ONLY a JSON response with these exact fields:

Question: "{question}"
Ground Truth: "{ground_truth}"
Response: "{response_text}"

Return JSON format:
{{
    "citation_present": true or false,
    "hallucination_present": true or false,
    "factscore": "completely right" or "somewhat correct" or "somewhat inaccurate" or "totally wrong",
    "confidence_markers_count": number,
    "uncertainty_markers_count": number
}}

Rules:
- citation_present: true if response contains citations or source-like phrases (e.g., "According to...", "Research shows...", "Studies indicate...")
- hallucination_present: true if response contradicts or significantly differs from ground truth
- factscore: Compare response accuracy against ground truth
- confidence_markers_count: Count phrases like "certainly," "definitely," "absolutely," "clearly," "obviously" in the response
- uncertainty_markers_count: Count phrases like "possibly," "might be," "perhaps," "likely," "probably," "may be" in the response
"""

    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "user", "content": prompt}],
            temperature=0.1,
            max_tokens=150
        )
        
        # Parse the JSON response
        result = json.loads(response.choices[0].message.content.strip())
        return result
        
    except Exception as e:
        print(f"Error processing analysis: {e}")
        return {
            "citation_present": False,
            "hallucination_present": False,
            "factscore": "unknown",
            "confidence_markers_count": 0,
            "uncertainty_markers_count": 0
        }

# -------------------------------
# Step 4: Process each file (ALL questions)
# -------------------------------
for input_file, output_file in files_to_process:
    print(f"\nProcessing {input_file} (ALL questions)...")
    
    # Load full dataset
    df = pd.read_csv(input_file)
    
    print(f"Analyzing {len(df)} responses from {input_file}...")
    
    # Initialize lists for new columns
    citation_present = []
    hallucination_present = []
    factscore = []
    confidence_markers_count = []
    uncertainty_markers_count = []
    
    # Analyze each response
    for idx, row in df.iterrows():
        print(f"  Analyzing response {idx+1}/{len(df)}: {row['question_text'][:50]}...")
        
        analysis = analyze_response_for_hallucination(
            row['question_text'],
            row['ground_truth'],
            row['response_text']
        )
        
        citation_present.append(analysis['citation_present'])
        hallucination_present.append(analysis['hallucination_present'])
        factscore.append(analysis['factscore'])
        confidence_markers_count.append(analysis['confidence_markers_count'])
        uncertainty_markers_count.append(analysis['uncertainty_markers_count'])
        
        # Small delay for API rate limits
        time.sleep(0.25)
        
        # Save progress every 50 questions
        if (idx + 1) % 50 == 0:
            print(f"    Completed {idx + 1} questions...")
    
    # Add new columns to dataframe
    df['citation_present'] = citation_present
    df['hallucination_present'] = hallucination_present
    df['factscore'] = factscore
    df['confidence_markers_count'] = confidence_markers_count
    df['uncertainty_markers_count'] = uncertainty_markers_count
    
    # Save to final file
    df.to_csv(output_file, index=False)
    
    print(f"Saved complete analysis to {output_file}")
    
print("\nComplete hallucination analysis finished for all models!")
print(f"\nFinal analysis files created:")
print(f"- qna_dataset_GPT3.5_final.csv")
print(f"- qna_dataset_GPT4o_final.csv") 
print(f"- qna_dataset_Claude3.5Sonnet_final.csv")
# Out:
# Starting hallucination analysis for all 3 models (ALL questions)...
#
# Processing qna_dataset_GPT3.5.csv (ALL questions)...
# Analyzing 400 responses from qna_dataset_GPT3.5.csv...
#   Analyzing response 1/400: What is the most common bird in the world?...
#   Analyzing response 2/400: What British sitcom that aired from 1979 to 1981 i...
#   Analyzing response 3/400: May 4, 1904 saw the US begin construction the Cana...
#   Analyzing response 4/400: "In a 2007 interview, which actor 'animatedly' bem...
#   Analyzing response 5/400: In which US state are the Catskill Mountains?...
#   Analyzing response 6/400: What was the name of Canada's first woman Prime Mi...
#   Analyzing response 7/400: Who was the former wife of war hero Leonard Cheshi...
#   Analyzing response 8/400: Who was the first British winner of the US Women’s...
#   Analyzing response 9/400: What type of beer does Homer Simpson drink?...
#   Analyzing response 10/400: Which role is being played in a recently released ...
#   Analyzing response 11/400: What was the surname of the butler played by Gordo...
#   Analyzing response 12/400: Which French phrase commonly used in English means...
#   Analyzing response 13/400: Tuesday marks the birthday of lat night tv host Da...
#   Analyzing response 14/400: The feathers of which bird are said to bring bad l...
#   Analyzing response 15/400: St Thomas's Abbey, Brno in the Czech Republic was ...
#   Analyzing response 16/400: What was introduced by the Volstead Act?...
#   Analyzing response 17/400: What word is used in betting slang for odds of fiv...
#   Analyzing response 18/400: In adventure literature, what lie in an unexplored...
#   Analyzing response 19/400: "Rodney you plonka" and "This time next year we'll...
#   Analyzing response 20/400: In medicine, if something is subcutaneous it is ap...
#   Analyzing response 21/400: "Complete the proverb; ""Hope for the best....""?"...
#   Analyzing response 22/400: The Asian Tsunami or Boxing day tsunami that hit T...
#   Analyzing response 23/400: The youngest ever member of the Order of Merit was...
#   Analyzing response 24/400: Which French aristocrat, revolutionary, politician...
#   Analyzing response 25/400: Where would a dewclaw usually be found?...
#   Analyzing response 26/400: In geometry, what name is given to a straight line...
#   Analyzing response 27/400: In 1725 Catherine the First succeeded which Russia...
#   Analyzing response 28/400: Which working-class dish gets its name from the fa...
#   Analyzing response 29/400: The husband of Lara Lewington, In which field is M...
#   Analyzing response 30/400: Raclette, Tilsit and Sbrinz are all types of which...
#   Analyzing response 31/400: Who wrote the 1984 Booker Prize winning novel 'Hot...
#   Analyzing response 32/400: Which TV series was won by a man named Paddy Doher...
#   Analyzing response 33/400: Precisely where were the Winter Olympics of 1932 a...
#   Analyzing response 34/400: In the TV sit-com 'Red Dwarf', what was the name o...
#   Analyzing response 35/400: What was the former name of Manchester airport ?...
#   Analyzing response 36/400: Which country shares a 530 km border with Saudi Ar...
#   Analyzing response 37/400: The peaceful overthrow of the government in Czecho...
#   Analyzing response 38/400: October 27, 1858 saw the birth of what totally bad...
#   Analyzing response 39/400: Theon Greyjoy, a character in the television serie...
#   Analyzing response 88/400: What has two chains of nucleotides, one more than ...
#   Analyzing response 89/400: What is needed by all known forms of life?...
#   Analyzing response 90/400: Interactions between plants and other organisms re...
#   Analyzing response 91/400: What is the water that falls from the sky called?...
#   Analyzing response 92/400: What is the name given to anything that has mass a...
#   Analyzing response 93/400: Carbon-14 dating is a method of what kind of datin...
#   Analyzing response 94/400: Most reptiles lay what kind of eggs?...
#   Analyzing response 95/400: What do you call accumulation of excess water in t...
#   Analyzing response 96/400: A type of what organism causes ergot, a disease th...
#   Analyzing response 97/400: What type of energy can be used to change the posi...
#   Analyzing response 98/400: Seawalls and breakwaters are built parallel to wha...
#   Analyzing response 99/400: What is the term for something in the environment ...
#   Analyzing response 100/400: What is the process where light bounces back from ...
#     Completed 100 questions...
#   Analyzing response 101/400: What property of ocean water increases rapidly as ...
#   Analyzing response 102/400: How do bipedal creatures walk?...
#   Analyzing response 103/400: A life cycle continues through reproduction and wh...
#   Analyzing response 104/400: The diagnosis of a disease or condition before the...
#   Analyzing response 105/400: What term is used to describe the process of remov...
#   Analyzing response 106/400: In many polychaetes, the parapodia are richly supp...
#   Analyzing response 107/400: Bond lengths are intermediate between covalent sin...
#   Analyzing response 108/400: What do you call plastids that contain the green p...
#   Analyzing response 109/400: The attraction of an atom for the electrons of a c...
#   Analyzing response 110/400: Since eddy currents and magnetic damping occur onl...
#   Analyzing response 111/400: What is the combination of tissues that provides a...
#   Analyzing response 112/400: The light-sensing cells in the retina are called r...
#   Analyzing response 113/400: What do you call a unique substance formed when tw...
#   Analyzing response 114/400: What do you call structures like a whale's pelvic ...
#   Analyzing response 115/400: Protozoa can be classified on the basis of how the...
#   Analyzing response 116/400: What basic structures of the nervous system innerv...
#   Analyzing response 117/400: What type of evolution often happens in species th...
#   Analyzing response 118/400: What type of vascular plants produce seeds in cone...
#   Analyzing response 119/400: Atmospheric pressure can be measured with what too...
#   Analyzing response 120/400: Would you find cells that contain a cell wall, a l...
#   Analyzing response 121/400: An atom that gains or loses electrons is called wh...
#   Analyzing response 122/400: What measures the amount of water in the air?...
#   Analyzing response 123/400: What kind of scientist is concerned with facets of...
#   Analyzing response 124/400: Which material used in oxyacetylene torches helps ...
#   Analyzing response 125/400: What forces in liquids are strong enough to keep t...
#   Analyzing response 126/400: What arteries carry oxygen-poor blood away from th...
#   Analyzing response 127/400: Some biochemical processes happen via sequences of...
#   Analyzing response 128/400: What are the most common dietary lipids?...
#   Analyzing response 129/400: The number of possible isomers increases tremendou...
#   Analyzing response 130/400: In the humid subtropical climate, summers are ____...
#   Analyzing response 131/400: The body contains how many types of muscle tissue?...
#   Analyzing response 132/400: What is the accelerating pattern of increasing pop...
#   Analyzing response 133/400: What do you call the sudden flow of mud down a slo...
#   Analyzing response 134/400: What do the liver, gallbladder, and pancreas contr...
#   Analyzing response 135/400: People with celiac disease have an immune response...
#   Analyzing response 136/400: What should a pregnant woman avoid while pregnant?...
#   Analyzing response 137/400: Near-earth asteroids cross paths with earth, meani...
#   Analyzing response 138/400: Skeletal muscles must work in pairs to move bones ...
#   Analyzing response 139/400: Evolution over a short period of time at the level...
#   Analyzing response 140/400: The purpose of scientific investigations generally...
#   Analyzing response 141/400: Which type of pressure forces fluid out of the cap...
#   Analyzing response 142/400: Surface tension forces between moleculse cause the...
#   Analyzing response 143/400: What is said about the speed of rotation in system...
#   Analyzing response 144/400: What is a benefit of low sulfur coal over high sul...
#   Analyzing response 145/400: Nitrogen is an important macronutrient because it ...
#   Analyzing response 146/400: Which energy is momentarily stored in tendons afte...
#   Analyzing response 147/400: What do you require to test a hypothesis?...
#   Analyzing response 148/400: What is made up of bands of cells that contract fo...
#   Analyzing response 149/400: Gases can undergo diffusion, or the opposite, whic...
#   Analyzing response 150/400: Most animals are in which clade?...
#     Completed 150 questions...
#   Analyzing response 151/400: Blood from the body enters what chamber of the hea...
#   Analyzing response 152/400: In multicellular organisms, specialized cells may ...
#   Analyzing response 153/400: What natural process allows water to return again ...
#   Analyzing response 154/400: What are the only organisms that can perform photo...
#   Analyzing response 155/400: What is friction that acts on objects that are mov...
#   Analyzing response 156/400: What substances function as a long-term energy sto...
#   Analyzing response 157/400: What are formed when crystals precipitate out from...
#   Analyzing response 158/400: Osseous tissue is the tissue that makes up what?...
#   Analyzing response 159/400: Where are temperatures the lowest?...
#   Analyzing response 160/400: What do we call the amount of time a substance is ...
#   Analyzing response 161/400: who controls the economic activity in a capitalist...
#   Analyzing response 162/400: when did speaking in tongues start in america...
#   Analyzing response 163/400: who wrote what i've done by linkin park...
#   Analyzing response 164/400: where was the episode beyond the wall filmed...
#   Analyzing response 165/400: who completed tyndales english translation of the ...
#   Analyzing response 166/400: which is the biggest building of the world...
#   Analyzing response 167/400: when did messi started playing for barca first tea...
#   Analyzing response 168/400: who is the person who devised the modern periodic ...
#   Analyzing response 169/400: what type of cells are primarily responsible for t...
#   Analyzing response 170/400: who wrote king arthur legend of the sword...
#   Analyzing response 171/400: who played ward cleaver on leave it to beaver...
#   Analyzing response 172/400: where does joffrey live in game of thrones...
#   Analyzing response 173/400: who played lady capulet in romeo and juliet...
#   Analyzing response 174/400: who sang sleeping single in a double bed...
#   Analyzing response 175/400: goalkeepers with most clean sheets in premier leag...
#   Analyzing response 176/400: who made the universal declaration of human rights...
#   Analyzing response 177/400: who are the three individuals named in a trust...
#   Analyzing response 178/400: when was the last time redskins won a playoff game...
#   Analyzing response 179/400: the greenback party and farmers' alliances both ca...
#   Analyzing response 180/400: largest national park in india in terms of area...
#   Analyzing response 181/400: when did mr. peabody and sherman come out...
#   Analyzing response 182/400: words on the front of great seal of the united sta...
#   Analyzing response 183/400: how many died during the bombing of hiroshima and ...
#   Analyzing response 184/400: when does episode 2 of american horror story seaso...
#   Analyzing response 185/400: who approves the head of the cabinet departments...
#   Analyzing response 186/400: who sings that's how strong my love is...
#   Analyzing response 187/400: what does gop in american politics stand for...
#   Analyzing response 188/400: in the absence of oxygen muscle cells may convert ...
#   Analyzing response 189/400: where will the next summer olympics be held 2020...
#   Analyzing response 190/400: what country has the most number of population...
#   Analyzing response 191/400: where are red blood cells made in the human body...
#   Analyzing response 192/400: what is the type and nature of shoprite...
#   Analyzing response 193/400: the sovereign status of native american tribes is ...
#   Analyzing response 194/400: where is the integration center located for most a...
#   Analyzing response 195/400: what is the fastest production bike in the world...
#   Analyzing response 196/400: who played aunt bea on andy griffith show...
#   Analyzing response 197/400: what channel is season 6 of nashville on...
#   Analyzing response 198/400: who in the bible almost sacrificed his son...
#   Analyzing response 199/400: when were the north west mounted police establishe...
#   Analyzing response 200/400: who has the authority to amend the constitution...
#     Completed 200 questions...
#   Analyzing response 201/400: when did the flyers win the stanley cup...
#   Analyzing response 202/400: where did the first societies in north america com...
#   Analyzing response 203/400: where are telomeres located in a normal chromosome...
#   Analyzing response 204/400: how many seats does rjd has in bihar...
#   Analyzing response 205/400: when did why don't we became a band...
#   Analyzing response 206/400: where did the british royal family live before buc...
#   Analyzing response 207/400: how many seasons of eric and jessie are there...
#   Analyzing response 208/400: where does the book of daniel take place...
#   Analyzing response 209/400: when does the tv show riverdale come back on...
#   Analyzing response 210/400: was star wars a book first or a movie...
#   Analyzing response 211/400: when was the last time the reds were in the playof...
#   Analyzing response 212/400: the andes mountains are found in which south ameri...
#   Analyzing response 213/400: when was tom petty and the heartbreakers formed...
#   Analyzing response 214/400: who starred in the streets of san francisco...
#   Analyzing response 215/400: who issued the coin rupee for the first time...
#   Analyzing response 216/400: when did women's basketball become an olympic spor...
#   Analyzing response 217/400: celine dion hit from falling into you album...
#   Analyzing response 218/400: when did kane browns song lose it come out...
#   Analyzing response 219/400: when did the movie titanic first come out...
#   Analyzing response 220/400: what was the name of the government set up in the ...
#   Analyzing response 221/400: when does series 9 of ncis los angeles start...
#   Analyzing response 222/400: when does the kingsman 2 movie come out...
#   Analyzing response 223/400: when was labor day established as a national holid...
#   Analyzing response 224/400: who played wicket in return of the jedi...
#   Analyzing response 225/400: when was the maple leaf first adopted as a symbol ...
#   Analyzing response 226/400: founded by the phoenicians around 800 b.c the city...
#   Analyzing response 227/400: what is the most rare blood type in south africa...
#   Analyzing response 228/400: who's being inducted into the pro football hall of...
#   Analyzing response 229/400: what is the red mushroom with white dots...
#   Analyzing response 230/400: who sang the original song our day will come...
#   Analyzing response 231/400: was sandy a tropical storm or a hurricane...
#   Analyzing response 232/400: when was the first movie made with sound...
#   Analyzing response 233/400: who has been eliminated from rupaul season 10...
#   Analyzing response 234/400: who sings where you lead i will follow...
#   Analyzing response 235/400: when was the transcontinental railroad started and...
#   Analyzing response 236/400: what article of the constitution outlines the proc...
#   Analyzing response 237/400: who won the national college football championship...
#   Analyzing response 238/400: who came up with the hammer and sickle...
#   Analyzing response 239/400: who does the ontario government borrow money from...
#   Analyzing response 240/400: what is the parker brothers most famous game...
#   Analyzing response 241/400: Who was nominated for a Golden Globe for best perf...
#   Analyzing response 242/400: Which automobile repair shop founded by Ryan Fried...
#   Analyzing response 243/400: Toño plays in goal for which Madrid football team?...
#   Analyzing response 244/400: Who was a Private in the marines who raised the fl...
#   Analyzing response 245/400: Michael Kelso is one of the male leads on the show...
#   Analyzing response 246/400: What company owns the shopping center that stands ...
#   Analyzing response 247/400: How many times was Bertha of Savoy's husband excom...
#   Analyzing response 248/400: Frederick and Louis Upton founded what American mu...
#   Analyzing response 249/400: The actor that played Herman Stiles on "Evening Sh...
#   Analyzing response 250/400: Are both the University of Hartford and Adamson Un...
#     Completed 250 questions...
#   Analyzing response 251/400: Are La Périchole and Jenůfa in the same language?...
#   Analyzing response 252/400: The directed one of the film which  Pat Gorman app...
#   Analyzing response 253/400: The actor that played Tim McManus on "Oz" starred ...
#   Analyzing response 254/400: Productions filmed at Space Studios Mancheter incl...
#   Analyzing response 255/400: Which tennis player is older, Billy Martin or Pave...
#   Analyzing response 256/400: When was the singer of "America's Sweetheart" born...
#   Analyzing response 257/400: Which breed of dog is fluffier, the Keeshond or th...
#   Analyzing response 258/400: Which University did the gymnastics coach, who rec...
#   Analyzing response 259/400: What two singles were played over the credits of t...
#   Analyzing response 260/400: Do Kathy Jordan and Marin Čilić have the same nati...
#   Analyzing response 261/400: Standing Ovation is a live album, by pianist and b...
#   Analyzing response 262/400: Which of the following was founded in Capitola, Ca...
#   Analyzing response 263/400: What city on the Silk Road means "Sandy place" in ...
#   Analyzing response 264/400: Who was born first,Todd Woodbridge or Lucie Hradec...
#   Analyzing response 265/400: In 2003, James Beaumont joined a professional foot...
#   Analyzing response 266/400: Who was born in an earlier year, Arantxa Sánchez V...
#   Analyzing response 267/400: In what city is the CBS station that features chil...
#   Analyzing response 268/400: What was the role played in "Sweet Charity" by the...
#   Analyzing response 269/400: How many awards did the alphabetically first anima...
#   Analyzing response 270/400: Mine is a song by Taylor Swift that was placed on ...
#   Analyzing response 271/400: What is the name of Ekaterina Gordeeva's husband, ...
#   Analyzing response 272/400: Are both rock bands Tapes 'n Tapes and Sloan based...
#   Analyzing response 273/400: Taylor Swift's song Out of the Woods is the 4th tr...
#   Analyzing response 274/400: Boiler Room, a 2000 American crime drama film, sta...
#   Analyzing response 275/400: Which documentary film was released first, Unchain...
#   Analyzing response 276/400: For which French king did Nicolas Bergier serve as...
#   Analyzing response 277/400: Deepak Tiwari is a Sspecial correspondent of an In...
#   Analyzing response 278/400: Break Every Rule World Tour is the fourth worldwid...
#   Analyzing response 279/400: Die Sexualität im Kulturkampf was by which Austria...
#   Analyzing response 280/400: Sleigh Ride is a piece of music written by compose...
#   Analyzing response 281/400: What station is near "The Giant Egg"?...
#   Analyzing response 282/400: Richard Labunski, a journalism professor at the Un...
#   Analyzing response 283/400: When was the former international footballer for t...
#   Analyzing response 284/400: What pair of American dicephalic parapagus twins h...
#   Analyzing response 285/400: What is the name of the winner of Celebrity Big Br...
#   Analyzing response 286/400: Which director is from Canada, Adam Smoluk or Hraf...
#   Analyzing response 287/400: What is the capacity of the stadium where Collisio...
#   Analyzing response 288/400: What do Noble Roman's and Ledo Pizza both have in ...
#   Analyzing response 289/400: What organization did the author of "Physics for F...
#   Analyzing response 290/400: Syed Noor and Paul Sloane, have which occupation i...
#   Analyzing response 338/400: A man was diagnosed to have myositis ossificans pr...
#   Analyzing response 339/400: An immunocompromised person presents to PGI with h...
#   Analyzing response 340/400: The free edge of which of of the following ligamen...
#   Analyzing response 341/400: Inseion of pectoralis major is at:...
#   Analyzing response 342/400: Hinge fracture is seen in:...
#   Analyzing response 343/400: Linitis plastica is found in A/E -...
#   Analyzing response 344/400: Axillary aery is divided into 3 pas by...
#   Analyzing response 345/400: A young child of 7 years age is seen with indurate...
#   Analyzing response 346/400: Nucleosides consist of?...
#   Analyzing response 347/400: The danger area of the face is so called because o...
#   Analyzing response 348/400: Human anatomical waste should be disposed in-...
#   Analyzing response 349/400: Sodium 2-mercapto ethane sulfonate is used as a pr...
#   Analyzing response 350/400: 7 years old child presents with a lesion in upper ...
#     Completed 350 questions...
#   Analyzing response 351/400: True about protein A of staph aureus -...
#   Analyzing response 352/400: Diganosis of polio -...
#   Analyzing response 353/400: An IQ between 50 & 70 would be classified as what ...
#   Analyzing response 354/400: Zero-order kinetics occur in the following drug wi...
#   Analyzing response 355/400: DOC for the treatment of Tularemia is:...
#   Analyzing response 356/400: A girl with normal stature and minimal or absent p...
#   Analyzing response 357/400: A child present with albinism. He should be evalua...
#   Analyzing response 358/400: Which feature is found only in the left lung?...
#   Analyzing response 359/400: Best absorbable monosaccharide...
#   Analyzing response 360/400: The following patient on Methotrexate, steroids an...
#   Analyzing response 361/400: Which scientific principle is the basis for thermo...
#   Analyzing response 362/400: Neutral substances are transported across the cell...
#   Analyzing response 363/400: What is meant by "Suppositions child" -...
#   Analyzing response 364/400: Most accurate and safest method to diagnose viable...
#   Analyzing response 365/400: The abnormal preoperative pulmonary function test ...
#   Analyzing response 366/400: A 24 years old primigravida wt = 57 kg, Hb 11.0 gm...
#   Analyzing response 367/400: Crown-Rump length of 120 mm means the gestational ...
#   Analyzing response 368/400: Alpha 1a selective blocker is...
#   Analyzing response 369/400: Quinsy is synonymous with -...
#   Analyzing response 370/400: Most common site of cholangiocarcinoma?...
#   Analyzing response 371/400: The immediate treatment of 10 kg weight infants pr...
#   Analyzing response 372/400: The most frequent cause of fracture of a root tip
# ...
#   Analyzing response 373/400: Cholangiocarcinoma most commonly metastases to-...
#   Analyzing response 374/400: Drug resistance in Tuberculosis is due to ?...
#   Analyzing response 375/400: IQ value of Imbecile according to weehsler Intelli...
#   Analyzing response 376/400: A Clinical sign of mania is?...
#   Analyzing response 377/400: The part of sequence of RNA coding for a protein a...
#   Analyzing response 378/400: Damage to pneumotaxic center produces ?...
#   Analyzing response 379/400: Painless effusions in joints in congenital syphili...
#   Analyzing response 380/400: The complication least likely to occur in a case o...
#   Analyzing response 381/400: In allergic pharyngitis, granularity in posterior ...
#   Analyzing response 382/400: Development of labia majora is from...
#   Analyzing response 383/400: Unilateral undescended around ?...
#   Analyzing response 384/400: The largest bursa in the body is:...
#   Analyzing response 385/400: A patient presented with a 1 X 1.5 cms growth on t...
#   Analyzing response 386/400: Bluish tympanic membrane is seen in:...
#   Analyzing response 387/400: Which one of the following marker is useful in dif...
#   Analyzing response 388/400: Ascospore is...
#   Analyzing response 389/400: Conclusive test for semen: Jharkhand 11...
#   Analyzing response 390/400: A 80 years old male presented with lung abscess in...
#   Analyzing response 391/400: Sigmoid volvulus rotation occurs...
#   Analyzing response 392/400: A 25 year old female underwent septic aboion, whic...
#   Analyzing response 393/400: What effect does hyperventilation have on the oxyg...
#   Analyzing response 394/400: Deletion of one alpha globin gene on one chromosom...
#   Analyzing response 395/400: True statement regarding Prevalence:...
#   Analyzing response 396/400: Thyroid hormone receptor which is predominantly ex...
#   Analyzing response 397/400: Investigation of choice for hydrocephalus in infan...
#   Analyzing response 398/400: Renal vein thrombosis (RVT) may be seen in :...
#   Analyzing response 399/400: In children below age of 8 years, high Level of cr...
#   Analyzing response 400/400: Middle aged man presents with complaints of weakne...
#     Completed 400 questions...
# Saved complete analysis to qna_dataset_GPT3.5_final.csv
#
# Processing qna_dataset_GPT4o.csv (ALL questions)...
# Analyzing 400 responses from qna_dataset_GPT4o.csv...
#   Analyzing response 1/400: What is the most common bird in the world?...
#   Analyzing response 2/400: What British sitcom that aired from 1979 to 1981 i...
#   Analyzing response 3/400: May 4, 1904 saw the US begin construction the Cana...
#   Analyzing response 4/400: "In a 2007 interview, which actor 'animatedly' bem...
#   Analyzing response 5/400: In which US state are the Catskill Mountains?...
#   Analyzing response 6/400: What was the name of Canada's first woman Prime Mi...
#   Analyzing response 7/400: Who was the former wife of war hero Leonard Cheshi...
#   Analyzing response 8/400: Who was the first British winner of the US Women’s...
#   Analyzing response 9/400: What type of beer does Homer Simpson drink?...
#   Analyzing response 10/400: Which role is being played in a recently released ...
#   Analyzing response 11/400: What was the surname of the butler played by Gordo...
#   Analyzing response 12/400: Which French phrase commonly used in English means...
#   Analyzing response 13/400: Tuesday marks the birthday of lat night tv host Da...
#   Analyzing response 14/400: The feathers of which bird are said to bring bad l...
#   Analyzing response 15/400: St Thomas's Abbey, Brno in the Czech Republic was ...
#   Analyzing response 16/400: What was introduced by the Volstead Act?...
#   Analyzing response 17/400: What word is used in betting slang for odds of fiv...
#   Analyzing response 18/400: In adventure literature, what lie in an unexplored...
#   Analyzing response 19/400: "Rodney you plonka" and "This time next year we'll...
#   Analyzing response 20/400: In medicine, if something is subcutaneous it is ap...
#   Analyzing response 21/400: "Complete the proverb; ""Hope for the best....""?"...
#   Analyzing response 22/400: The Asian Tsunami or Boxing day tsunami that hit T...
#   Analyzing response 23/400: The youngest ever member of the Order of Merit was...
#   Analyzing response 24/400: Which French aristocrat, revolutionary, politician...
#   Analyzing response 25/400: Where would a dewclaw usually be found?...
#   Analyzing response 26/400: In geometry, what name is given to a straight line...
#   Analyzing response 27/400: In 1725 Catherine the First succeeded which Russia...
#   Analyzing response 28/400: Which working-class dish gets its name from the fa...
#   Analyzing response 29/400: The husband of Lara Lewington, In which field is M...
#   Analyzing response 30/400: Raclette, Tilsit and Sbrinz are all types of which...
#   Analyzing response 31/400: Who wrote the 1984 Booker Prize winning novel 'Hot...
#   Analyzing response 32/400: Which TV series was won by a man named Paddy Doher...
#   Analyzing response 80/400: In World War I, the British soldiers were nickname...
#   Analyzing response 81/400: What causes light to refract?...
#   Analyzing response 82/400: The number, size, shape, and banding pattern of ch...
#   Analyzing response 83/400: What is an example of a metaloid element?...
#   Analyzing response 84/400: Volcano chains form as an oceanic plate moves over...
#   Analyzing response 85/400: The voltage and current are exactly in phase in a ...
#   Analyzing response 86/400: What is the name of the body system that fights to...
#   Analyzing response 87/400: What is the process that ventilates lungs called?...
#   Analyzing response 88/400: What has two chains of nucleotides, one more than ...
#   Analyzing response 89/400: What is needed by all known forms of life?...
#   Analyzing response 90/400: Interactions between plants and other organisms re...
#   Analyzing response 91/400: What is the water that falls from the sky called?...
#   Analyzing response 92/400: What is the name given to anything that has mass a...
#   Analyzing response 93/400: Carbon-14 dating is a method of what kind of datin...
#   Analyzing response 94/400: Most reptiles lay what kind of eggs?...
#   Analyzing response 95/400: What do you call accumulation of excess water in t...
#   Analyzing response 96/400: A type of what organism causes ergot, a disease th...
#   Analyzing response 97/400: What type of energy can be used to change the posi...
#   Analyzing response 98/400: Seawalls and breakwaters are built parallel to wha...
#   Analyzing response 99/400: What is the term for something in the environment ...
#   Analyzing response 100/400: What is the process where light bounces back from ...
#     Completed 100 questions...
#   Analyzing response 101/400: What property of ocean water increases rapidly as ...
#   Analyzing response 102/400: How do bipedal creatures walk?...
#   Analyzing response 103/400: A life cycle continues through reproduction and wh...
#   Analyzing response 104/400: The diagnosis of a disease or condition before the...
#   Analyzing response 105/400: What term is used to describe the process of remov...
#   Analyzing response 106/400: In many polychaetes, the parapodia are richly supp...
#   Analyzing response 107/400: Bond lengths are intermediate between covalent sin...
#   Analyzing response 108/400: What do you call plastids that contain the green p...
#   Analyzing response 109/400: The attraction of an atom for the electrons of a c...
#   Analyzing response 110/400: Since eddy currents and magnetic damping occur onl...
#   Analyzing response 111/400: What is the combination of tissues that provides a...
#   Analyzing response 112/400: The light-sensing cells in the retina are called r...
#   Analyzing response 113/400: What do you call a unique substance formed when tw...
#   Analyzing response 114/400: What do you call structures like a whale's pelvic ...
#   Analyzing response 115/400: Protozoa can be classified on the basis of how the...
#   Analyzing response 116/400: What basic structures of the nervous system innerv...
#   Analyzing response 117/400: What type of evolution often happens in species th...
#   Analyzing response 118/400: What type of vascular plants produce seeds in cone...
#   Analyzing response 119/400: Atmospheric pressure can be measured with what too...
#   Analyzing response 120/400: Would you find cells that contain a cell wall, a l...
#   Analyzing response 121/400: An atom that gains or loses electrons is called wh...
#   Analyzing response 122/400: What measures the amount of water in the air?...
#   Analyzing response 123/400: What kind of scientist is concerned with facets of...
#   Analyzing response 124/400: Which material used in oxyacetylene torches helps ...
#   Analyzing response 125/400: What forces in liquids are strong enough to keep t...
#   Analyzing response 126/400: What arteries carry oxygen-poor blood away from th...
#   Analyzing response 127/400: Some biochemical processes happen via sequences of...
#   Analyzing response 128/400: What are the most common dietary lipids?...
#   Analyzing response 129/400: The number of possible isomers increases tremendou...
#   Analyzing response 130/400: In the humid subtropical climate, summers are ____...
#   Analyzing response 131/400: The body contains how many types of muscle tissue?...
#   Analyzing response 132/400: What is the accelerating pattern of increasing pop...
#   Analyzing response 133/400: What do you call the sudden flow of mud down a slo...
#   Analyzing response 134/400: What do the liver, gallbladder, and pancreas contr...
#   Analyzing response 135/400: People with celiac disease have an immune response...
#   Analyzing response 136/400: What should a pregnant woman avoid while pregnant?...
#   Analyzing response 137/400: Near-earth asteroids cross paths with earth, meani...
#   Analyzing response 138/400: Skeletal muscles must work in pairs to move bones ...
#   Analyzing response 139/400: Evolution over a short period of time at the level...
#   Analyzing response 140/400: The purpose of scientific investigations generally...
#   Analyzing response 141/400: Which type of pressure forces fluid out of the cap...
#   Analyzing response 142/400: Surface tension forces between moleculse cause the...
#   Analyzing response 143/400: What is said about the speed of rotation in system...
#   Analyzing response 144/400: What is a benefit of low sulfur coal over high sul...
#   Analyzing response 145/400: Nitrogen is an important macronutrient because it ...
#   Analyzing response 146/400: Which energy is momentarily stored in tendons afte...
#   Analyzing response 147/400: What do you require to test a hypothesis?...
#   Analyzing response 148/400: What is made up of bands of cells that contract fo...
#   Analyzing response 149/400: Gases can undergo diffusion, or the opposite, whic...
#   Analyzing response 150/400: Most animals are in which clade?...
#     Completed 150 questions...
#   Analyzing response 151/400: Blood from the body enters what chamber of the hea...
#   Analyzing response 152/400: In multicellular organisms, specialized cells may ...
#   Analyzing response 153/400: What natural process allows water to return again ...
#   Analyzing response 154/400: What are the only organisms that can perform photo...
#   Analyzing response 155/400: What is friction that acts on objects that are mov...
#   Analyzing response 156/400: What substances function as a long-term energy sto...
#   Analyzing response 157/400: What are formed when crystals precipitate out from...
#   Analyzing response 158/400: Osseous tissue is the tissue that makes up what?...
#   Analyzing response 159/400: Where are temperatures the lowest?...
#   Analyzing response 160/400: What do we call the amount of time a substance is ...
#   Analyzing response 161/400: who controls the economic activity in a capitalist...
#   Analyzing response 162/400: when did speaking in tongues start in america...
#   Analyzing response 163/400: who wrote what i've done by linkin park...
#   Analyzing response 164/400: where was the episode beyond the wall filmed...
#   Analyzing response 165/400: who completed tyndales english translation of the ...
#   Analyzing response 166/400: which is the biggest building of the world...
#   Analyzing response 167/400: when did messi started playing for barca first tea...
#   Analyzing response 168/400: who is the person who devised the modern periodic ...
#   Analyzing response 169/400: what type of cells are primarily responsible for t...
#   Analyzing response 170/400: who wrote king arthur legend of the sword...
#   Analyzing response 171/400: who played ward cleaver on leave it to beaver...
#   Analyzing response 172/400: where does joffrey live in game of thrones...
#   Analyzing response 173/400: who played lady capulet in romeo and juliet...
#   Analyzing response 174/400: who sang sleeping single in a double bed...
#   Analyzing response 175/400: goalkeepers with most clean sheets in premier leag...
#   Analyzing response 176/400: who made the universal declaration of human rights...
#   Analyzing response 177/400: who are the three individuals named in a trust...
#   Analyzing response 178/400: when was the last time redskins won a playoff game...
#   Analyzing response 179/400: the greenback party and farmers' alliances both ca...
#   Analyzing response 180/400: largest national park in india in terms of area...
#   Analyzing response 181/400: when did mr. peabody and sherman come out...
#   Analyzing response 182/400: words on the front of great seal of the united sta...
#   Analyzing response 183/400: how many died during the bombing of hiroshima and ...
# ...
#   Analyzing response 207/400: how many seasons of eric and jessie are there...
#   Analyzing response 208/400: where does the book of daniel take place...
#   Analyzing response 209/400: when does the tv show riverdale come back on...
#   Analyzing response 210/400: was star wars a book first or a movie...
#   Analyzing response 211/400: when was the last time the reds were in the playof...
#   Analyzing response 212/400: the andes mountains are found in which south ameri...
#   Analyzing response 213/400: when was tom petty and the heartbreakers formed...
#   Analyzing response 214/400: who starred in the streets of san francisco...
#   Analyzing response 215/400: who issued the coin rupee for the first time...
#   Analyzing response 216/400: when did women's basketball become an olympic spor...
#   Analyzing response 217/400: celine dion hit from falling into you album...
#   Analyzing response 218/400: when did kane browns song lose it come out...
#   Analyzing response 219/400: when did the movie titanic first come out...
#   Analyzing response 220/400: what was the name of the government set up in the ...
#   Analyzing response 221/400: when does series 9 of ncis los angeles start...
#   Analyzing response 222/400: when does the kingsman 2 movie come out...
#   Analyzing response 223/400: when was labor day established as a national holid...
#   Analyzing response 224/400: who played wicket in return of the jedi...
#   Analyzing response 225/400: when was the maple leaf first adopted as a symbol ...
#   Analyzing response 226/400: founded by the phoenicians around 800 b.c the city...
#   Analyzing response 227/400: what is the most rare blood type in south africa...
#   Analyzing response 228/400: who's being inducted into the pro football hall of...
#   Analyzing response 229/400: what is the red mushroom with white dots...
#   Analyzing response 230/400: who sang the original song our day will come...
#   Analyzing response 231/400: was sandy a tropical storm or a hurricane...
#   Analyzing response 232/400: when was the first movie made with sound...
#   Analyzing response 233/400: who has been eliminated from rupaul season 10...
#   Analyzing response 234/400: who sings where you lead i will follow...
#   Analyzing response 235/400: when was the transcontinental railroad started and...
#   Analyzing response 236/400: what article of the constitution outlines the proc...
#   Analyzing response 237/400: who won the national college football championship...
#   Analyzing response 238/400: who came up with the hammer and sickle...
#   Analyzing response 239/400: who does the ontario government borrow money from...
#   Analyzing response 240/400: what is the parker brothers most famous game...
#   Analyzing response 241/400: Who was nominated for a Golden Globe for best perf...
#   Analyzing response 242/400: Which automobile repair shop founded by Ryan Fried...
#   Analyzing response 243/400: Toño plays in goal for which Madrid football team?...
#   Analyzing response 244/400: Who was a Private in the marines who raised the fl...
#   Analyzing response 245/400: Michael Kelso is one of the male leads on the show...
#   Analyzing response 246/400: What company owns the shopping center that stands ...
#   Analyzing response 247/400: How many times was Bertha of Savoy's husband excom...
#   Analyzing response 248/400: Frederick and Louis Upton founded what American mu...
#   Analyzing response 249/400: The actor that played Herman Stiles on "Evening Sh...
#   Analyzing response 250/400: Are both the University of Hartford and Adamson Un...
#     Completed 250 questions...
#   Analyzing response 251/400: Are La Périchole and Jenůfa in the same language?...
#   Analyzing response 252/400: The directed one of the film which  Pat Gorman app...
#   Analyzing response 253/400: The actor that played Tim McManus on "Oz" starred ...
#   Analyzing response 254/400: Productions filmed at Space Studios Mancheter incl...
#   Analyzing response 255/400: Which tennis player is older, Billy Martin or Pave...
#   Analyzing response 256/400: When was the singer of "America's Sweetheart" born...
#   Analyzing response 303/400: Which casting director known as a specialist in ca...
#   Analyzing response 304/400: Devil May Cry 3: Dante's Awakening is a game that ...
#   Analyzing response 305/400: Félix Loustau (] ) (25 December 1922 – 5 January 2...
#   Analyzing response 306/400: Shaoyang and Haiyang, are in which country?...
#   Analyzing response 307/400: What is the location identifier of the Geneva Airp...
#   Analyzing response 308/400: In ancient Roman religion, Fontus or Fons (plural ...
#   Analyzing response 309/400: What film is older The Incredible Journey or The T...
#   Analyzing response 310/400: Georg Unger played the role of Siegfried in which ...
#   Analyzing response 311/400: The M62 has 7 miles that are shared with which Man...
#   Analyzing response 312/400: Among David Bowers and John G. Adolfiwho was an Am...
#   Analyzing response 313/400: In what year was the emperor of whom Elizaveta Vor...
#   Analyzing response 314/400: What owned and operated by LC International LLC Fr...
#   Analyzing response 315/400: In which year did the husband of Jean Case of the ...
#   Analyzing response 316/400: Who is the director of Attack on Titan?...
#   Analyzing response 317/400: Which is marketed primarily to a younger audience,...
#   Analyzing response 318/400: When did the first films for the universe containi...
#   Analyzing response 319/400: What player with the nickname "Pistol Pete" lost t...
#   Analyzing response 320/400: Who has performed with more band, Trey Anastasio o...
#   Analyzing response 321/400: Keyhole bullet entry is a feature of -...
#   Analyzing response 322/400: Osteoblastic metastasis is seen -...
#   Analyzing response 323/400: A 60-year-old male has bone pain, vertebral collap...
#   Analyzing response 324/400: What is the most appropriate for diagnosis of CBD ...
#   Analyzing response 325/400: Excess dietary intake of carbohydrates increases t...
#   Analyzing response 326/400: Reactivation tuberculosis and primary squamous cel...
#   Analyzing response 327/400: In epidemics measles vaccine is to be given within...
#   Analyzing response 328/400: Geographic lytic lesions in the vault of the skull...
#   Analyzing response 329/400: Most common cause of rubeosis iridis is...
#   Analyzing response 330/400: Oho-toluidine test measures the levels of:-...
#   Analyzing response 331/400: Type of collagen forming basement membrane of kidn...
#   Analyzing response 332/400: Myofibroblast is seen in -...
#   Analyzing response 333/400: During a voluntary movement, the Golgi tendon orga...
#   Analyzing response 334/400: Which one of the following drugs exacerbate reflux...
#   Analyzing response 335/400: Food poisoning in "Canned food" is usually due to:...
#   Analyzing response 336/400: Modified BPS consists of :...
#   Analyzing response 337/400: Empyema necessitans is defined as so when ?...
#   Analyzing response 338/400: A man was diagnosed to have myositis ossificans pr...
#   Analyzing response 339/400: An immunocompromised person presents to PGI with h...
#   Analyzing response 340/400: The free edge of which of of the following ligamen...
#   Analyzing response 341/400: Inseion of pectoralis major is at:...
#   Analyzing response 342/400: Hinge fracture is seen in:...
#   Analyzing response 343/400: Linitis plastica is found in A/E -...
#   Analyzing response 344/400: Axillary aery is divided into 3 pas by...
#   Analyzing response 345/400: A young child of 7 years age is seen with indurate...
#   Analyzing response 346/400: Nucleosides consist of?...
#   Analyzing response 347/400: The danger area of the face is so called because o...
#   Analyzing response 348/400: Human anatomical waste should be disposed in-...
#   Analyzing response 349/400: Sodium 2-mercapto ethane sulfonate is used as a pr...
#   Analyzing response 350/400: 7 years old child presents with a lesion in upper ...
#     Completed 350 questions...
#   Analyzing response 351/400: True about protein A of staph aureus -...
#   Analyzing response 352/400: Diganosis of polio -...
#   Analyzing response 353/400: An IQ between 50 & 70 would be classified as what ...
#   Analyzing response 354/400: Zero-order kinetics occur in the following drug wi...
#   Analyzing response 355/400: DOC for the treatment of Tularemia is:...
#   Analyzing response 356/400: A girl with normal stature and minimal or absent p...
#   Analyzing response 357/400: A child present with albinism. He should be evalua...
#   Analyzing response 358/400: Which feature is found only in the left lung?...
#   Analyzing response 359/400: Best absorbable monosaccharide...
#   Analyzing response 360/400: The following patient on Methotrexate, steroids an...
#   Analyzing response 361/400: Which scientific principle is the basis for thermo...
#   Analyzing response 362/400: Neutral substances are transported across the cell...
#   Analyzing response 363/400: What is meant by "Suppositions child" -...
#   Analyzing response 364/400: Most accurate and safest method to diagnose viable...
#   Analyzing response 365/400: The abnormal preoperative pulmonary function test ...
#   Analyzing response 366/400: A 24 years old primigravida wt = 57 kg, Hb 11.0 gm...
#   Analyzing response 367/400: Crown-Rump length of 120 mm means the gestational ...
#   Analyzing response 368/400: Alpha 1a selective blocker is...
#   Analyzing response 369/400: Quinsy is synonymous with -...
#   Analyzing response 370/400: Most common site of cholangiocarcinoma?...
#   Analyzing response 371/400: The immediate treatment of 10 kg weight infants pr...
#   Analyzing response 372/400: The most frequent cause of fracture of a root tip
# ...
#   Analyzing response 373/400: Cholangiocarcinoma most commonly metastases to-...
#   Analyzing response 374/400: Drug resistance in Tuberculosis is due to ?...
#   Analyzing response 375/400: IQ value of Imbecile according to weehsler Intelli...
#   Analyzing response 376/400: A Clinical sign of mania is?...
#   Analyzing response 377/400: The part of sequence of RNA coding for a protein a...
#   Analyzing response 378/400: Damage to pneumotaxic center produces ?...
#   Analyzing response 379/400: Painless effusions in joints in congenital syphili...
#   Analyzing response 380/400: The complication least likely to occur in a case o...
#   Analyzing response 381/400: In allergic pharyngitis, granularity in posterior ...
#   Analyzing response 382/400: Development of labia majora is from...
#   Analyzing response 383/400: Unilateral undescended around ?...
#   Analyzing response 384/400: The largest bursa in the body is:...
#   Analyzing response 385/400: A patient presented with a 1 X 1.5 cms growth on t...
#   Analyzing response 386/400: Bluish tympanic membrane is seen in:...
#   Analyzing response 387/400: Which one of the following marker is useful in dif...
#   Analyzing response 388/400: Ascospore is...
#   Analyzing response 389/400: Conclusive test for semen: Jharkhand 11...
#   Analyzing response 390/400: A 80 years old male presented with lung abscess in...
#   Analyzing response 391/400: Sigmoid volvulus rotation occurs...
#   Analyzing response 392/400: A 25 year old female underwent septic aboion, whic...
#   Analyzing response 393/400: What effect does hyperventilation have on the oxyg...
#   Analyzing response 394/400: Deletion of one alpha globin gene on one chromosom...
#   Analyzing response 395/400: True statement regarding Prevalence:...
#   Analyzing response 396/400: Thyroid hormone receptor which is predominantly ex...
#   Analyzing response 397/400: Investigation of choice for hydrocephalus in infan...
#   Analyzing response 398/400: Renal vein thrombosis (RVT) may be seen in :...
#   Analyzing response 399/400: In children below age of 8 years, high Level of cr...
#   Analyzing response 400/400: Middle aged man presents with complaints of weakne...
#     Completed 400 questions...
# Saved complete analysis to qna_dataset_Claude3.5Sonnet_final.csv
#
# Complete hallucination analysis finished for all models!
#
# Final analysis files created:
# - qna_dataset_GPT3.5_final.csv
# - qna_dataset_GPT4o_final.csv
# - qna_dataset_Claude3.5Sonnet_final.csv

# %% [markdown]
# ## Summary Statistics for Final Files
#
# ### Purpose: Show summary statistics for the 3 final analysis files

# %%
import pandas as pd

# -------------------------------
# Final files to analyze
# -------------------------------
files_to_analyze = [
    'qna_dataset_GPT3.5_final.csv',
    'qna_dataset_GPT4o_final.csv',
    'qna_dataset_Claude3.5Sonnet_final.csv'
]

# -------------------------------
# Generate summary for each file
# -------------------------------
for input_file in files_to_analyze:
    print(f"\n{'='*60}")
    print(f"SUMMARY FOR {input_file}")
    print(f"{'='*60}")
    
    # Load the dataset
    df = pd.read_csv(input_file)
    
    # Extract the new columns
    citation_present = df['citation_present'].tolist()
    hallucination_present = df['hallucination_present'].tolist()
    factscore = df['factscore'].tolist()
    confidence_markers_count = df['confidence_markers_count'].tolist()
    uncertainty_markers_count = df['uncertainty_markers_count'].tolist()
    
    # Show summary statistics
    print(f"Summary for {input_file}:")
    print(f"  Total responses: {len(df)}")
    print(f"  Citations present: {sum(citation_present)}/{len(citation_present)} ({sum(citation_present)/len(citation_present)*100:.1f}%)")
    print(f"  Hallucinations detected: {sum(hallucination_present)}/{len(hallucination_present)} ({sum(hallucination_present)/len(hallucination_present)*100:.1f}%)")
    print(f"  FactScore distribution: {pd.Series(factscore).value_counts().to_dict()}")
    print(f"  Average confidence markers: {sum(confidence_markers_count)/len(confidence_markers_count):.1f}")
    print(f"  Average uncertainty markers: {sum(uncertainty_markers_count)/len(uncertainty_markers_count):.1f}")
# Out:
# ============================================================
# SUMMARY FOR qna_dataset_GPT3.5_final.csv
# ============================================================
# Summary for qna_dataset_GPT3.5_final.csv:
#   Total responses: 400
#   Citations present: 1/400 (0.2%)
#   Hallucinations detected: 75/400 (18.8%)
#   FactScore distribution: {'completely right': 210, 'somewhat inaccurate': 87, 'somewhat correct': 87, 'totally wrong': 16}
#   Average confidence markers: 0.0
#   Average uncertainty markers: 0.1
#
# ============================================================
# SUMMARY FOR qna_dataset_GPT4o_final.csv
# ============================================================
# Summary for qna_dataset_GPT4o_final.csv:
#   Total responses: 400
#   Citations present: 14/400 (3.5%)
#   Hallucinations detected: 47/400 (11.8%)
#   FactScore distribution: {'completely right': 255, 'somewhat correct': 79, 'somewhat inaccurate': 55, 'totally wrong': 11}
#   Average confidence markers: 0.0
#   Average uncertainty markers: 0.1
#
# ============================================================
# SUMMARY FOR qna_dataset_Claude3.5Sonnet_final.csv
# ============================================================
# Summary for qna_dataset_Claude3.5Sonnet_final.csv:
#   Total responses: 400
#   Citations present: 26/400 (6.5%)
#   Hallucinations detected: 49/400 (12.2%)
#   FactScore distribution: {'completely right': 224, 'somewhat correct': 114, 'somewhat inaccurate': 52, 'totally wrong': 10}
#   Average confidence markers: 0.0
#   Average uncertainty markers: 0.1
